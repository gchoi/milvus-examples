# %% [markdown]
# # 목적
# * 이 예제에서는 5개의 테이블에 대한 table description excel 파일을 Milvus DB에 넣는 실습을 진행합니다.
# * 이 예제에서 사용하는 데이터는 `./data/`폴더 내에 있는 5개 엑셀 파일을 가지고 실습합니다.

# %%
import os
import json
from typing import Dict, List
import textwrap
import logging
import pandas as pd
from pathlib import Path, PosixPath
from dotenv import load_dotenv

from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_milvus import Milvus

from helper import find_project_root, load_tables_description

# %% [markdown]
# ## 0. 프로젝트 경로 초기 셋팅

# %%
ROOT_PATH = find_project_root()
DATA_PATH = ROOT_PATH.joinpath("shilla/example_human_gen/data")

load_dotenv(ROOT_PATH.joinpath(".env"))
# Out:
# True

# %% [markdown]
# ## 1. Table description 불러오기
# * 미리 저장되어 있는 table description을 불러옵니다.
# * 저장 경로는 DATA_PATH 입니다.

# %%
table_description = load_tables_description(DATA_PATH, False) # CHESS 함수 c/p

# %%
table_description
# Out:
# {'daily_finished_goods_agg': {'critn_date': {'original_column_name': 'critn_date',
#    'column_name': 'creation date',
#    'column_description': 'created year, month and date explained as 8 yyyymmdd digits',
#    'data_format': 'text',
#    'value_description': ''},
#   'fact_nm': {'original_column_name': 'fact_nm',
#    'column_name': 'factory name',
#    'column_description': 'name of factory',
#    'data_format': 'text',
#    'value_description': ''},
#   'line_cd': {'original_column_name': 'line_cd',
#    'column_name': 'line code',
#    'column_description': 'grouped process line code',
#    'data_format': 'text',
#    'value_description': ''},
#   'line_nm': {'original_column_name': 'line_nm',
#    'column_name': 'line name',
#    'column_description': 'grouped process line name',
#    'data_format': 'text',
#    'value_description': ''},
#   'item_cd': {'original_column_name': 'item_cd',
#    'column_name': 'item code',
#    'column_description': 'item code name',
#    'data_format': 'text',
#    'value_description': ''},
#   'finished_qty': {'original_column_name': 'finished_qty',
#    'column_name': 'finished quantity',
#    'column_description': 'quantity of finished products',
#    'data_format': 'integer',
#    'value_description': ''},
#   'reg_id': {'original_column_name': 'reg_id',
#    'column_name': 'registration id',
#    'column_description': 'account id who registrated this data',
#    'data_format': 'text',
#    'value_description': ''},
#   'reg_dts': {'original_column_name': 'reg_dts',
#    'column_name': 'registration datetimes',
#    'column_description': 'datetime when this data is registrated',
#    'data_format': 'text',
#    'value_description': ''}},
#  'erp_dm_subc_edited': {'subl_code': {'original_column_name': 'subl_code',
#    'column_name': 'sub level code',
#    'column_description': 'sub level code which contains multiple sub categories',
#    'data_format': 'integer',
#    'value_description': ''},
#   'subc_code': {'original_column_name': 'subc_code',
#    'column_name': 'sub category code',
#    'column_description': 'sub category code which should be used with line code',
#    'data_format': 'integer',
#    'value_description': ''},
#   'subc_name': {'original_column_name': 'subc_name',
#    'column_name': 'sub category name',
#    'column_description': 'sub category name which should be used with line name or factory name',
#    'data_format': 'text',
#    'value_description': ''}},
#  'erp_pm_ncr_mod': {'defect_date': {'original_column_name': 'defect_date',
#    'column_name': 'defect date',
#    'column_description': 'date of the defect products produced',
#    'data_format': 'text',
#    'value_description': ''},
#   'fact_nm': {'original_column_name': 'fact_nm',
#    'column_name': 'factory name',
#    'column_description': "factory name which should be used with subc_code when subl_code is '776'",
#    'data_format': 'text',
#    'value_description': ''},
#   'plant_nm': {'original_column_name': 'plant_nm',
#    'column_name': 'plant name',
#    'column_description': '',
#    'data_format': 'text',
#    'value_description': ''},
#   'line_cd': {'original_column_name': 'line_cd',
#    'column_name': 'line code',
#    'column_description': "grouped process line code which should be used with subc_code when subl_code is '706'",
#    'data_format': 'text',
#    'value_description': ''},
#   'line_nm': {'original_column_name': 'line_nm',
#    'column_name': 'line name',
#    'column_description': "grouped process line name which should be used with subc_name when subl_code is '706'",
#    'data_format': 'text',
#    'value_description': ''},
#   'item_cd': {'original_column_name': 'item_cd',
#    'column_name': 'item code',
#    'column_description': '',
#    'data_format': 'text',
#    'value_description': ''},
#   'item_type_nm': {'original_column_name': 'item_type_nm',
#    'column_name': 'item type name',
#    'column_description': '',
#    'data_format': 'text',
#    'value_description': ''},
#   'defect_qty': {'original_column_name': 'defect_qty',
#    'column_name': 'defect quantity',
#    'column_description': 'quantity of defective products',
#    'data_format': 'integer',
#    'value_description': ''},
#   'reg_id': {'original_column_name': 'reg_id',
#    'column_name': 'registration id',
#    'column_description': 'account id who registrated this data',
#    'data_format': 'text',
#    'value_description': ''},
#   'reg_dts': {'original_column_name': 'reg_dts',
#    'column_name': 'registration datetimes',
#    'column_description': 'datetime when this data is registrated',
#    'data_format': 'text',
#    'value_description': ''}},
#  'monthly_production_metrics': {'critn_yyymm': {'original_column_name': 'critn_yyymm',
#    'column_name': 'creation yyymm',
#    'column_description': 'created year and month explained as 6 yyyymm digits',
#    'data_format': 'text',
#    'value_description': ''},
#   'fact_nm': {'original_column_name': 'fact_nm',
#    'column_name': 'factory name',
#    'column_description': 'name of factory',
#    'data_format': 'text',
#    'value_description': ''},
#   'line_cd': {'original_column_name': 'line_cd',
#    'column_name': 'line code',
#    'column_description': 'grouped process line code',
#    'data_format': 'text',
#    'value_description': ''},
#   'line_nm': {'original_column_name': 'line_nm',
#    'column_name': 'line name',
#    'column_description': 'grouped process line name',
#    'data_format': 'text',
#    'value_description': ''},
#   'plant_nm': {'original_column_name': 'plant_nm',
#    'column_name': 'plant name',
#    'column_description': 'name of plant',
#    'data_format': 'text',
#    'value_description': ''},
#   'work_time': {'original_column_name': 'work_time',
#    'column_name': 'work time',
#    'column_description': 'period of time when the plant is operated',
#    'data_format': 'integer',
#    'value_description': ''},
#   'downtime': {'original_column_name': 'downtime',
#    'column_name': 'downtime',
#    'column_description': 'preriod of time when the plant is unavailable or not operational',
#    'data_format': 'integer',
#    'value_description': ''},
#   'breakdown_time': {'original_column_name': 'breakdown_time',
#    'column_name': 'breakdown time',
#    'column_description': 'period of breakdown time of the plant',
#    'data_format': 'integer',
#    'value_description': ''},
#   'idle_time': {'original_column_name': 'idle_time',
#    'column_name': 'idle time',
#    'column_description': 'idle time which means a period of time when an asset or employee is available but not being productive',
#    'data_format': 'integer',
#    'value_description': ''},
#   'work_qty': {'original_column_name': 'work_qty',
#    'column_name': 'work quantity',
#    'column_description': 'production quantity',
#    'data_format': 'integer',
#    'value_description': ''},
#   'defect_qty': {'original_column_name': 'defect_qty',
#    'column_name': 'defect quantity',
#    'column_description': 'defect quantity',
#    'data_format': 'integer',
#    'value_description': ''},
#   'breakdown_cnt': {'original_column_name': 'breakdown_cnt',
#    'column_name': 'breakdown count',
#    'column_description': 'frequency of breakdown',
#    'data_format': 'integer',
#    'value_description': ''},
#   'idle_cnt': {'original_column_name': 'idle_cnt',
#    'column_name': 'idle count',
#    'column_description': 'frequency of idle time',
#    'data_format': 'integer',
#    'value_description': ''},
#   'total_standard_time': {'original_column_name': 'total_standard_time',
#    'column_name': 'total standard time',
#    'column_description': 'total period of production',
#    'data_format': 'integer',
#    'value_description': ''},
#   'availability_rate': {'original_column_name': 'availability_rate',
#    'column_name': 'availability rate',
#    'column_description': 'ratio of work time which is calculated with this formula, work_time / nullif(work_time + downtime, 0) * 100',
#    'data_format': 'real',
#    'value_description': ''},
#   'performance_rate': {'original_column_name': 'performance_rate',
#    'column_name': 'performance rate',
#    'column_description': 'ratio of perfomance time which is calculated with this formula, total_standard_time / nullif(work_time, 0) * 100',
#    'data_format': 'real',
#    'value_description': ''},
#   'quality_rate': {'original_column_name': 'quality_rate',
#    'column_name': 'quality rate',
#    'column_description': 'ratio of non-defective products which is calculated with this formula, (work_qty - defect_qty) / nullif(work_qty, 0) * 100',
#    'data_format': 'real',
#    'value_description': ''},
#   'idle_rate': {'original_column_name': 'idle_rate',
#    'column_name': 'idle rate',
#    'column_description': 'ratio of idle time which is calculated with this formula, idle_time / nullif(work_time + downtime + idle_time, 0) * 100',
#    'data_format': 'real',
#    'value_description': ''},
#   'breakdown_rate': {'original_column_name': 'breakdown_rate',
#    'column_name': 'breakdown rate',
#    'column_description': 'ratio of breakdown time which is calculated with this formula, breakdown_time / nullif(work_time + downtime, 0) * 100',
#    'data_format': 'real',
#    'value_description': ''},
#   'mtbf': {'original_column_name': 'mtbf',
#    'column_name': 'Mean Time Between Failures',
#    'column_description': 'mean time between failures which represents facility reliability. Calculated with this formula, work_time / nullif(breakdown_cnt, 0)',
#    'data_format': 'real',
#    'value_description': ''},
#   'mttr': {'original_column_name': 'mttr',
#    'column_name': 'Mean Time To Repair',
#    'column_description': 'mean time to repair which represents maintenance of equipment. Calculated with this formula, round(breakdown_time / nullif(breakdown_cnt, 0), 0)',
#    'data_format': 'real',
#    'value_description': ''},
#   'reg_id': {'original_column_name': 'reg_id',
#    'column_name': 'registration id',
#    'column_description': 'account id who registrated this data',
#    'data_format': 'text',
#    'value_description': ''},
#   'reg_dts': {'original_column_name': 'reg_dts',
#    'column_name': 'registration datetimes',
#    'column_description': 'datetime when this data is registrated',
#    'data_format': 'text',
#    'value_description': ''}},
#  'item_master': {'item_cd': {'original_column_name': 'item_cd',
#    'column_name': 'item code',
#    'column_description': 'unique code of each item',
#    'data_format': 'text',
#    'value_description': ''},
#   'item_nm': {'original_column_name': 'item_nm',
#    'column_name': 'item name',
#    'column_description': 'item name',
#    'data_format': 'text',
#    'value_description': ''},
#   'item_alias': {'original_column_name': 'item_alias',
#    'column_name': 'item alias',
#    'column_description': 'item alias which are optional',
#    'data_format': 'text',
#    'value_description': ''},
#   'item_tmp_weight': {'original_column_name': 'item_tmp_weight',
#    'column_name': 'item temperature weight',
#    'column_description': 'not used',
#    'data_format': 'integer',
#    'value_description': ''},
#   'item_attr': {'original_column_name': 'item_attr',
#    'column_name': 'item attr',
#    'column_description': 'not used',
#    'data_format': 'text',
#    'value_description': ''},
#   'lot_size': {'original_column_name': 'lot_size',
#    'column_name': 'lot size',
#    'column_description': 'not used',
#    'data_format': 'integer',
#    'value_description': ''},
#   'item_type': {'original_column_name': 'item_type',
#    'column_name': 'item type',
#    'column_description': 'type code of the item',
#    'data_format': 'text',
#    'value_description': ''},
#   'type_nm': {'original_column_name': 'type_nm',
#    'column_name': 'type name',
#    'column_description': 'type name of the item',
#    'data_format': 'text',
#    'value_description': ''},
#   'class_cd': {'original_column_name': 'class_cd',
#    'column_name': 'class code',
#    'column_description': 'not used',
#    'data_format': 'text',
#    'value_description': ''},
#   'class_nm': {'original_column_name': 'class_nm',
#    'column_name': 'class name',
#    'column_description': 'not used',
#    'data_format': 'text',
#    'value_description': ''},
#   'group_cd': {'original_column_name': 'group_cd',
#    'column_name': 'group code',
#    'column_description': 'not used',
#    'data_format': 'text',
#    'value_description': ''},
#   'group_nm': {'original_column_name': 'group_nm',
#    'column_name': 'group name',
#    'column_description': 'not used',
#    'data_format': 'text',
#    'value_description': ''},
#   'fact_cd': {'original_column_name': 'fact_cd',
#    'column_name': 'factory code',
#    'column_description': 'not used',
#    'data_format': 'text',
#    'value_description': ''},
#   'fact_nm': {'original_column_name': 'fact_nm',
#    'column_name': 'factory name',
#    'column_description': 'name of factory that produced the item',
#    'data_format': 'text',
#    'value_description': ''},
#   'corp_nm': {'original_column_name': 'corp_nm',
#    'column_name': 'corporation name',
#    'column_description': 'name of corporation that owns the factory',
#    'data_format': 'text',
#    'value_description': ''},
#   'item_uni': {'original_column_name': 'item_uni',
#    'column_name': 'item unit',
#    'column_description': 'not used',
#    'data_format': 'text',
#    'value_description': ''},
#   'cust_cd': {'original_column_name': 'cust_cd',
#    'column_name': 'customer code',
#    'column_description': 'a unique identifier assigned to each customer',
#    'data_format': 'text',
#    'value_description': ''},
#   'cust_nm': {'original_column_name': 'cust_nm',
#    'column_name': 'customer name',
#    'column_description': 'the official name of the customer',
#    'data_format': 'text',
#    'value_description': ''},
#   'cust_alias': {'original_column_name': 'cust_alias',
#    'column_name': 'customer alias',
#    'column_description': 'a shortened name used to refer the customer',
#    'data_format': 'text',
#    'value_description': ''},
#   'ccenter_cd': {'original_column_name': 'ccenter_cd',
#    'column_name': 'cost center code',
#    'column_description': '(optional)',
#    'data_format': 'text',
#    'value_description': ''},
#   'reg_id': {'original_column_name': 'reg_id',
#    'column_name': 'registration id',
#    'column_description': 'account id who registrated this data',
#    'data_format': 'text',
#    'value_description': ''},
#   'reg_dts': {'original_column_name': 'reg_dts',
#    'column_name': 'registration datetimes',
#    'column_description': 'datetime when this data is registrated',
#    'data_format': 'text',
#    'value_description': ''}}}

# %% [markdown]
# ## 2. Document 형태로 재구성
# * CHESS에 있는 코드를 참고하여 재구성
# * LangChain에서 제공하는 클래스인 `Document`에 정의
#   * page_content (유사도로 비교하는 실제 탐색 정보) -> table_name, column_name, column_description 추가
#   * metadata (해당 정보에 대한 메타데이터) -> 나머지 정보 입력 (아래 코드 참고)
# * page_content에 들어가는 정보가 핵심입니다. 사용자의 질문과 유사도를 계산하여 가장 유사도가 높은 정보를 찾은 실질적인 탐색정보.
# * page_content에 되도록 많은 정보가 들어갈수록 성능은 무조건 좋아지지만, 실제 제품으로 사용할 때 모든 정보가 들어가지 않음.
# * 데이터 거버넌스 측면에서 중 컬럼에 뜻, 메타 정보 등은 매우 중요하며, 미리 구축해두지 않았더라도, Vivity One을 사용하기 위해선 초기에 반드시 필요한 셋팅임.
# * 따라서 column_description을 page_content에 배치시킴. 추가로 테이블 이름과 컬럼명을 같이 넣어 해당 column_description에 해당하는 테이블 명과 컬럼명을 같이 알 수 있게함.
# * json 형태로 page_content에 추가함.

# %%
# table name docs
# CHESS 코드를 약간 변형함
def gen_docs(table_description: Dict[str, Dict])-> List[Document]:
    docs = []
    for table_name, columns in table_description.items():
        for column_name, column_info in columns.items():
            metadata = {
                "table_name": table_name,
                "original_column_name": column_name,
                "column_name": column_info.get('column_name', ''),
                "column_description": column_info.get('column_description', ''),
                "value_description": column_info.get('value_description', '') if True else ""
            }
            # print(column_info)
            # print("a")
            for key in ['column_description']:
                if column_info.get(key, '').strip():
                    json_str = {
                        "table": table_name,
                        "column": column_name,
                        "column_description": column_info.get(key, '')
                    }
                    page_content = textwrap.dedent(f'''
                    ```json
                    {json_str}
                    ```
                    ''')
                    docs.append(Document(page_content=page_content, metadata=metadata))
    return docs

# %%
docs = gen_docs(table_description)
len(docs)
# Out:
# 63

# %%
docs[0:3]
# Out:
# [Document(metadata={'table_name': 'daily_finished_goods_agg', 'original_column_name': 'critn_date', 'column_name': 'creation date', 'column_description': 'created year, month and date explained as 8 yyyymmdd digits', 'value_description': ''}, page_content="\n```json\n{'table': 'daily_finished_goods_agg', 'column': 'critn_date', 'column_description': 'created year, month and date explained as 8 yyyymmdd digits'}\n```\n"),
#  Document(metadata={'table_name': 'daily_finished_goods_agg', 'original_column_name': 'fact_nm', 'column_name': 'factory name', 'column_description': 'name of factory', 'value_description': ''}, page_content="\n```json\n{'table': 'daily_finished_goods_agg', 'column': 'fact_nm', 'column_description': 'name of factory'}\n```\n"),
#  Document(metadata={'table_name': 'daily_finished_goods_agg', 'original_column_name': 'line_cd', 'column_name': 'line code', 'column_description': 'grouped process line code', 'value_description': ''}, page_content="\n```json\n{'table': 'daily_finished_goods_agg', 'column': 'line_cd', 'column_description': 'grouped process line code'}\n```\n")]

# %% [markdown]
# ## 3. Milvus vector store 저장
# * 임베딩 함수는 openai 임베딩 함수를 사용함.
# * 이는 추후 로컬 모델로 변경해서 테스트 해야함.
# * 본 예제에서는 AI01에 데이터를 넣는 예제임.
#   * (한번 생성한 collenction이 있는데 from_document로 넣으면 그냥 넘기는 듯 합니다)

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
# AI01 Standalone Milvus DB
URI = "http://10.128.0.20:19530"

# %%
vector_store_saved = Milvus.from_documents(
    documents=docs,
    embedding=embeddings,
    collection_name="shilla_data_descriptions",
    connection_args={"uri":URI}
)

# %% [markdown]
# ## 4. Milvus vector store 데이터 조회
# * Milvus DB에서 데이터 조회, 컬렉션 리스트 조회 등 가능.

# %%
from pymilvus import Collection, utility, connections

# 1. Milvus 서버에 접속 (URI 입력)
connections.connect(alias = "standalone-ai01", uri=URI)

# 2. 전체 컬렉션 리스트
collection_names = utility.list_collections(using="standalone-ai01")

# 3. 컬렉션 객체 불러오기
collection = Collection("shilla_data_descriptions", using="standalone-ai01") 

collection_names, collection
# Out:
# (['shilla_test_20250526_openai_embedding_3_large',
#   'shilla_data_descriptions',
#   'shilla_test_20250526_ollama_bge_m3_1',
#   'shilla_test_20250526_ollama_bge_m3',
#   'shilla_test_20250526_openai_embedding_3_large_1'],
#  <Collection>:
#  -------------
#  <name>: shilla_data_descriptions
#  <description>:
#  <schema>: {'auto_id': True, 'description': '', 'fields': [{'name': 'text', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 65535}}, {'name': 'pk', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': True}, {'name': 'vector', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 3072}}, {'name': 'table_name', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 65535}}, {'name': 'original_column_name', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 65535}}, {'name': 'column_name', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 65535}}, {'name': 'column_description', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 65535}}, {'name': 'value_description', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 65535}}], 'enable_dynamic_field': False})

# %%
for field in collection.schema.fields:
    print(f" - 이름: {field.name}, 타입: {field.dtype}, 벡터 차원: {getattr(field, 'dim', 'N/A')}")
# Out:
#  - 이름: text, 타입: 21, 벡터 차원: None
#  - 이름: pk, 타입: 5, 벡터 차원: None
#  - 이름: vector, 타입: 101, 벡터 차원: 3072
#  - 이름: table_name, 타입: 21, 벡터 차원: None
#  - 이름: original_column_name, 타입: 21, 벡터 차원: None
#  - 이름: column_name, 타입: 21, 벡터 차원: None
#  - 이름: column_description, 타입: 21, 벡터 차원: None
#  - 이름: value_description, 타입: 21, 벡터 차원: None

# %% [markdown]
# ## 5. Milvus vector store 검색
# * 유사도 검색하는 방법
# * 유사도 점수까지 함깨 내는 방법
# * retriever로 사용하는 방법
#   * filter 같은 파라미터를 사용하면 metadata에서 먼저 filtering 거친 후 탐색할 수도 있음 (탐색범위를 줄여주는)

# %%
vector_store_loaded = Milvus(
    embedding_function=embeddings,
    collection_name="shilla_data_descriptions",
    connection_args={"uri": URI}
)

# %%
results = vector_store_loaded.similarity_search(
    "What is the average work time for the 정삭 process at the 장산공장 plant, produced in May 2024?",
    k=3
)
results
# Out:
# [Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'work_time', 'column_name': 'work time', 'column_description': 'period of time when the plant is operated', 'value_description': '', 'pk': 458330752954111767}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'work_time', 'column_description': 'period of time when the plant is operated'}\n```\n"),
#  Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'work_time', 'column_name': 'work time', 'column_description': 'period of time when the plant is operated', 'value_description': '', 'pk': 458330752954111839}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'work_time', 'column_description': 'period of time when the plant is operated'}\n```\n"),
#  Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'work_time', 'column_name': 'work time', 'column_description': 'period of time when the plant is operated', 'value_description': '', 'pk': 457879227621186019}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'work_time', 'column_description': 'period of time when the plant is operated'}\n```\n")]

# %%
results = vector_store_loaded.similarity_search_with_score(
    "What is the average work time for the 정삭 process at the 장산공장 plant, produced in May 2024?",
    k=3
)
results
# Out:
# [(Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'work_time', 'column_name': 'work time', 'column_description': 'period of time when the plant is operated', 'value_description': '', 'pk': 458330752954111767}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'work_time', 'column_description': 'period of time when the plant is operated'}\n```\n"),
#   1.3856805562973022),
#  (Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'work_time', 'column_name': 'work time', 'column_description': 'period of time when the plant is operated', 'value_description': '', 'pk': 458330752954111839}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'work_time', 'column_description': 'period of time when the plant is operated'}\n```\n"),
#   1.3856805562973022),
#  (Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'work_time', 'column_name': 'work time', 'column_description': 'period of time when the plant is operated', 'value_description': '', 'pk': 457879227621186019}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'work_time', 'column_description': 'period of time when the plant is operated'}\n```\n"),
#   1.3858177661895752)]

# %%
retriever = vector_store_loaded.as_retriever(search_type="mmr", search_kwargs={"k": 3})                 
retriever.invoke("What is the average work time for the 정삭 process at the 장산공장 plant, produced in May 2024?")
# Out:
# [Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'work_time', 'column_name': 'work time', 'column_description': 'period of time when the plant is operated', 'value_description': '', 'pk': 458330752954111767}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'work_time', 'column_description': 'period of time when the plant is operated'}\n```\n"),
#  Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'mttr', 'column_name': 'Mean Time To Repair', 'column_description': 'mean time to repair which represents maintenance of equipment. Calculated with this formula, round(breakdown_time / nullif(breakdown_cnt, 0), 0)', 'value_description': '', 'pk': 458330752954111782}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'mttr', 'column_description': 'mean time to repair which represents maintenance of equipment. Calculated with this formula, round(breakdown_time / nullif(breakdown_cnt, 0), 0)'}\n```\n"),
#  Document(metadata={'table_name': 'monthly_production_metrics', 'original_column_name': 'idle_time', 'column_name': 'idle time', 'column_description': 'idle time which means a period of time when an asset or employee is available but not being productive', 'value_description': '', 'pk': 457879227621186022}, page_content="\n```json\n{'table': 'monthly_production_metrics', 'column': 'idle_time', 'column_description': 'idle time which means a period of time when an asset or employee is available but not being productive'}\n```\n")]
